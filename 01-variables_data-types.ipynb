# %% [markdown]
# <h4>Variables and Data Types</h4>

# %%
course_name = "Introduction to Computational Social Sciences"
credit = 3
enrolled = True
syllabus = None

# %%
type(course_name), type(credit), type(enrolled), type(syllabus)
# Out:
# (str, int, bool, NoneType)

# %%
student_name = "Doğukan Başaran"
gpa = 3.37

# %%
type(student_name), type(gpa)
# Out:
# (str, float)

# %%
course_name, course_credit = "Introduction to Computational Social Sciences", 3

# %%
print("Course name is " + course_name + " and course credit is " + str(course_credit) + ".")
# Out:
# Course name is Introduction to Computational Social Sciences and course credit is 3.
